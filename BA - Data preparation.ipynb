# %% [markdown]
# ### Importing required libraries

# %%
#BeautifulSoup: A library used to parse HTML and extract data from web pages.
from bs4 import BeautifulSoup
#requests: A library to send HTTP requests to websites and get the HTML of web pages.
import requests
#pandas: A library used tool for data manipulation and analysis
import pandas
#csv: A module for writing and handling CSV (Comma Separated Values) files.
import csv
#re: Python’s module for regular expressions, used to match patterns in strings.
import re

# %%
review_df = pandas.read_csv('BA_reviews_dataset.csv')

# %%
review_df.head()
# Out:
#                                      Title             Author         Country  \
# 0              "never fly with them again"     Erika Greyling  United Kingdom
# 1       "still have not heard any updates"          S Wozniak   United States
# 2                   "cabin crew were nice"   Barnaby Emmerson  United Kingdom
# 3  "support staff wash their hands of you"  Charlotte Parsons  United Kingdom
# 4          "no fuss, no bother experience"       R. Wrightman          Canada
#
#    Rating  Overall_Rating Date_Published Type_of_Traveller        Seat_Type  \
# 0     1.0            10.0     2024-11-03    Couple Leisure    Economy Class
# 1     3.0            10.0     2024-11-03    Couple Leisure  Premium Economy
# 2     7.0            10.0     2024-11-03    Family Leisure    Economy Class
# 3     1.0            10.0     2024-11-02    Family Leisure  Premium Economy
# 4     9.0            10.0     2024-11-02      Solo Leisure    Economy Class
#
#                             Route Recommended  \
# 0       Munich to London Heathrow          no
# 1              Heathrow to Boston          no
# 2  Los Angeles to London Heathrow         yes
# 3             Vancouver to London          no
# 4            Vancouver to Gatwick         yes
#
#                                              Content
# 0  ✅ Trip Verified |   I recently travelled from ...
# 1  Not Verified |  I paid for seats 80 A and B on...
# 2  Not Verified | The flight wasn’t that bad, alt...
# 3  ✅ Trip Verified |  I decided to treat myself a...
# 4  Not Verified |  I was very impressed with thei...

# %%
review_df.dtypes
# Out:
# Title                 object
# Author                object
# Country               object
# Rating               float64
# Overall_Rating       float64
# Date_Published        object
# Type_of_Traveller     object
# Seat_Type             object
# Route                 object
# Recommended           object
# Content               object
# dtype: object

# %% [markdown]
# ### Data Preparation / Data Cleaning

# %%
# Change date column from object to datetime
#Before using pd.to_datetime(), you can remove the ordinal suffixes ("th", "nd", "st", "rd") using a regular expression.
# Sample DataFrame with problematic date strings
review_df = pandas.read_csv('BA_reviews_dataset.csv')

# Function to remove ordinal suffixes (e.g., "th", "nd", "st", "rd")
def remove_ordinal_suffix(date_str):
    return re.sub(r'(\d+)(st|nd|rd|th)', r'\1', date_str)

# Apply the function to the 'Date_Published' column
review_df['Date_Published'] = review_df['Date_Published'].apply(remove_ordinal_suffix)

# Now convert the cleaned strings to datetime, inferring format for mixed cases
review_df['Date_Published'] = pandas.to_datetime(review_df['Date_Published'], errors='coerce')

# Check the DataFrame to confirm the conversion
print(review_df.dtypes)
# Out:
# Title                        object
# Author                       object
# Country                      object
# Rating                      float64
# Overall_Rating              float64
# Date_Published       datetime64[ns]
# Type_of_Traveller            object
# Seat_Type                    object
# Route                        object
# Recommended                  object
# Content                      object
# dtype: object

# %%
#removes leading and trailing spaces from all columns in a DataFrame
review_df = review_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
review_df.head()
# Out:
#                                      Title             Author         Country  \
# 0              "never fly with them again"     Erika Greyling  United Kingdom
# 1       "still have not heard any updates"          S Wozniak   United States
# 2                   "cabin crew were nice"   Barnaby Emmerson  United Kingdom
# 3  "support staff wash their hands of you"  Charlotte Parsons  United Kingdom
# 4          "no fuss, no bother experience"       R. Wrightman          Canada
#
#    Rating  Overall_Rating Date_Published Type_of_Traveller        Seat_Type  \
# 0     1.0            10.0     2024-11-03    Couple Leisure    Economy Class
# 1     3.0            10.0     2024-11-03    Couple Leisure  Premium Economy
# 2     7.0            10.0     2024-11-03    Family Leisure    Economy Class
# 3     1.0            10.0     2024-11-02    Family Leisure  Premium Economy
# 4     9.0            10.0     2024-11-02      Solo Leisure    Economy Class
#
#                             Route Recommended  \
# 0       Munich to London Heathrow          no
# 1              Heathrow to Boston          no
# 2  Los Angeles to London Heathrow         yes
# 3             Vancouver to London          no
# 4            Vancouver to Gatwick         yes
#
#                                              Content
# 0  ✅ Trip Verified |   I recently travelled from ...
# 1  Not Verified |  I paid for seats 80 A and B on...
# 2  Not Verified | The flight wasn’t that bad, alt...
# 3  ✅ Trip Verified |  I decided to treat myself a...
# 4  Not Verified |  I was very impressed with thei...

# %%
#removes "" from the title column
review_df['Title'] = review_df['Title'].apply(lambda x: x.replace('"', ''))
review_df
# Out:
#                                       Title             Author  \
# 0                 never fly with them again     Erika Greyling
# 1          still have not heard any updates          S Wozniak
# 2                      cabin crew were nice   Barnaby Emmerson
# 3     support staff wash their hands of you  Charlotte Parsons
# 4             no fuss, no bother experience       R. Wrightman
# ...                                     ...                ...
# 3405        British Airways customer review            J Smith
# 3406        British Airways customer review       Boone Pieter
# 3407        British Airways customer review             R King
# 3408        British Airways customer review       Tom Gleinser
# 3409        British Airways customer review        H Blackhall
#
#              Country  Rating  Overall_Rating Date_Published Type_of_Traveller  \
# 0     United Kingdom     1.0            10.0     2024-11-03    Couple Leisure
# 1      United States     3.0            10.0     2024-11-03    Couple Leisure
# 2     United Kingdom     7.0            10.0     2024-11-03    Family Leisure
# 3     United Kingdom     1.0            10.0     2024-11-02    Family Leisure
# 4             Canada     9.0            10.0     2024-11-02      Solo Leisure
# ...              ...     ...             ...            ...               ...
# 3405   United States     1.0            10.0     2014-12-18               NaN
# 3406     Netherlands     7.0            10.0     2014-12-18               NaN
# 3407  United Kingdom     8.0            10.0     2014-12-18               NaN
# 3408   United States     2.0            10.0     2014-12-18               NaN
# 3409  United Kingdom     3.0            10.0     2014-12-18               NaN
#
#             Seat_Type                           Route Recommended  \
# 0       Economy Class       Munich to London Heathrow          no
# 1     Premium Economy              Heathrow to Boston          no
# 2       Economy Class  Los Angeles to London Heathrow         yes
# 3     Premium Economy             Vancouver to London          no
# 4       Economy Class            Vancouver to Gatwick         yes
# ...               ...                             ...         ...
# 3405   Business Class                             NaN          no
# 3406   Business Class                             NaN         yes
# 3407      First Class                             NaN         yes
# 3408   Business Class                             NaN          no
# 3409    Economy Class                             NaN          no
#
#                                                 Content
# 0     ✅ Trip Verified |   I recently travelled from ...
# 1     Not Verified |  I paid for seats 80 A and B on...
# 2     Not Verified | The flight wasn’t that bad, alt...
# 3     ✅ Trip Verified |  I decided to treat myself a...
# 4     Not Verified |  I was very impressed with thei...
# ...                                                 ...
# 3405  I cannot believe that BA calls their plane fro...
# 3406  AMS-LHR-JNB and CPT-LHR-AMS in club. 767 betwe...
# 3407  Travelled JFK - LHR late November. The Concord...
# 3408  We flew "Business/1st class" from London to Du...
# 3409  LGW-TFS in November 2014. Flight left Gatwick ...
#
# [3410 rows x 11 columns]

# %%
# the above steps did not work for all rows,therefore, implemented the function below
# Define a function to clean the title
def clean_title(title):
    if isinstance(title, str):  # Ensure the title is a string
        title = re.sub(r'[“”‘’"]', '', title)  # Remove any type of quote characters
        title = title.strip()  # Remove leading/trailing spaces
    return title

# Apply this cleaning function to the Title column
review_df['Title'] = review_df['Title'].apply(clean_title)

# For extra measure, strip all string columns
review_df = review_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# Check the result
review_df.head()
# Out:
#                                    Title             Author         Country  \
# 0              never fly with them again     Erika Greyling  United Kingdom
# 1       still have not heard any updates          S Wozniak   United States
# 2                   cabin crew were nice   Barnaby Emmerson  United Kingdom
# 3  support staff wash their hands of you  Charlotte Parsons  United Kingdom
# 4          no fuss, no bother experience       R. Wrightman          Canada
#
#    Rating  Overall_Rating Date_Published Type_of_Traveller        Seat_Type  \
# 0     1.0            10.0     2024-11-03    Couple Leisure    Economy Class
# 1     3.0            10.0     2024-11-03    Couple Leisure  Premium Economy
# 2     7.0            10.0     2024-11-03    Family Leisure    Economy Class
# 3     1.0            10.0     2024-11-02    Family Leisure  Premium Economy
# 4     9.0            10.0     2024-11-02      Solo Leisure    Economy Class
#
#                             Route Recommended  \
# 0       Munich to London Heathrow          no
# 1              Heathrow to Boston          no
# 2  Los Angeles to London Heathrow         yes
# 3             Vancouver to London          no
# 4            Vancouver to Gatwick         yes
#
#                                              Content
# 0  ✅ Trip Verified |   I recently travelled from ...
# 1  Not Verified |  I paid for seats 80 A and B on...
# 2  Not Verified | The flight wasn’t that bad, alt...
# 3  ✅ Trip Verified |  I decided to treat myself a...
# 4  Not Verified |  I was very impressed with thei...

# %%
# Capitalize only the first letter of the first word in each sentence in the Title column
review_df['Title'] = review_df['Title'].str.capitalize()
review_df.head()
# Out:
#                                    Title             Author         Country  \
# 0              Never fly with them again     Erika Greyling  United Kingdom
# 1       Still have not heard any updates          S Wozniak   United States
# 2                   Cabin crew were nice   Barnaby Emmerson  United Kingdom
# 3  Support staff wash their hands of you  Charlotte Parsons  United Kingdom
# 4          No fuss, no bother experience       R. Wrightman          Canada
#
#    Rating  Overall_Rating Date_Published Type_of_Traveller        Seat_Type  \
# 0     1.0            10.0     2024-11-03    Couple Leisure    Economy Class
# 1     3.0            10.0     2024-11-03    Couple Leisure  Premium Economy
# 2     7.0            10.0     2024-11-03    Family Leisure    Economy Class
# 3     1.0            10.0     2024-11-02    Family Leisure  Premium Economy
# 4     9.0            10.0     2024-11-02      Solo Leisure    Economy Class
#
#                             Route Recommended  \
# 0       Munich to London Heathrow          no
# 1              Heathrow to Boston          no
# 2  Los Angeles to London Heathrow         yes
# 3             Vancouver to London          no
# 4            Vancouver to Gatwick         yes
#
#                                              Content
# 0  ✅ Trip Verified |   I recently travelled from ...
# 1  Not Verified |  I paid for seats 80 A and B on...
# 2  Not Verified | The flight wasn’t that bad, alt...
# 3  ✅ Trip Verified |  I decided to treat myself a...
# 4  Not Verified |  I was very impressed with thei...

# %%
#Capitalizes the first letter of each word in the author column, while the rest of the letters will be lowercase.
review_df['Author'] = review_df['Author'].str.title()
review_df
# Out:
#                                       Title             Author  \
# 0                 Never fly with them again     Erika Greyling
# 1          Still have not heard any updates          S Wozniak
# 2                      Cabin crew were nice   Barnaby Emmerson
# 3     Support staff wash their hands of you  Charlotte Parsons
# 4             No fuss, no bother experience       R. Wrightman
# ...                                     ...                ...
# 3405        British airways customer review            J Smith
# 3406        British airways customer review       Boone Pieter
# 3407        British airways customer review             R King
# 3408        British airways customer review       Tom Gleinser
# 3409        British airways customer review        H Blackhall
#
#              Country  Rating  Overall_Rating Date_Published Type_of_Traveller  \
# 0     United Kingdom     1.0            10.0     2024-11-03    Couple Leisure
# 1      United States     3.0            10.0     2024-11-03    Couple Leisure
# 2     United Kingdom     7.0            10.0     2024-11-03    Family Leisure
# 3     United Kingdom     1.0            10.0     2024-11-02    Family Leisure
# 4             Canada     9.0            10.0     2024-11-02      Solo Leisure
# ...              ...     ...             ...            ...               ...
# 3405   United States     1.0            10.0     2014-12-18               NaN
# 3406     Netherlands     7.0            10.0     2014-12-18               NaN
# 3407  United Kingdom     8.0            10.0     2014-12-18               NaN
# 3408   United States     2.0            10.0     2014-12-18               NaN
# 3409  United Kingdom     3.0            10.0     2014-12-18               NaN
#
#             Seat_Type                           Route Recommended  \
# 0       Economy Class       Munich to London Heathrow          no
# 1     Premium Economy              Heathrow to Boston          no
# 2       Economy Class  Los Angeles to London Heathrow         yes
# 3     Premium Economy             Vancouver to London          no
# 4       Economy Class            Vancouver to Gatwick         yes
# ...               ...                             ...         ...
# 3405   Business Class                             NaN          no
# 3406   Business Class                             NaN         yes
# 3407      First Class                             NaN         yes
# 3408   Business Class                             NaN          no
# 3409    Economy Class                             NaN          no
#
#                                                 Content
# 0     ✅ Trip Verified |   I recently travelled from ...
# 1     Not Verified |  I paid for seats 80 A and B on...
# 2     Not Verified | The flight wasn’t that bad, alt...
# 3     ✅ Trip Verified |  I decided to treat myself a...
# 4     Not Verified |  I was very impressed with thei...
# ...                                                 ...
# 3405  I cannot believe that BA calls their plane fro...
# 3406  AMS-LHR-JNB and CPT-LHR-AMS in club. 767 betwe...
# 3407  Travelled JFK - LHR late November. The Concord...
# 3408  We flew "Business/1st class" from London to Du...
# 3409  LGW-TFS in November 2014. Flight left Gatwick ...
#
# [3410 rows x 11 columns]

# %%
#replace NaN from overall rating
review_df['Overall_Rating'] = review_df['Overall_Rating'].fillna(10)
review_df
# Out:
#                                       Title             Author  \
# 0                 Never fly with them again     Erika Greyling
# 1          Still have not heard any updates          S Wozniak
# 2                      Cabin crew were nice   Barnaby Emmerson
# 3     Support staff wash their hands of you  Charlotte Parsons
# 4             No fuss, no bother experience       R. Wrightman
# ...                                     ...                ...
# 3405        British airways customer review            J Smith
# 3406        British airways customer review       Boone Pieter
# 3407        British airways customer review             R King
# 3408        British airways customer review       Tom Gleinser
# 3409        British airways customer review        H Blackhall
#
#              Country  Rating  Overall_Rating Date_Published Type_of_Traveller  \
# 0     United Kingdom     1.0            10.0     2024-11-03    Couple Leisure
# 1      United States     3.0            10.0     2024-11-03    Couple Leisure
# 2     United Kingdom     7.0            10.0     2024-11-03    Family Leisure
# 3     United Kingdom     1.0            10.0     2024-11-02    Family Leisure
# 4             Canada     9.0            10.0     2024-11-02      Solo Leisure
# ...              ...     ...             ...            ...               ...
# 3405   United States     1.0            10.0     2014-12-18               NaN
# 3406     Netherlands     7.0            10.0     2014-12-18               NaN
# 3407  United Kingdom     8.0            10.0     2014-12-18               NaN
# 3408   United States     2.0            10.0     2014-12-18               NaN
# 3409  United Kingdom     3.0            10.0     2014-12-18               NaN
#
#             Seat_Type                           Route Recommended  \
# 0       Economy Class       Munich to London Heathrow          no
# 1     Premium Economy              Heathrow to Boston          no
# 2       Economy Class  Los Angeles to London Heathrow         yes
# 3     Premium Economy             Vancouver to London          no
# 4       Economy Class            Vancouver to Gatwick         yes
# ...               ...                             ...         ...
# 3405   Business Class                             NaN          no
# 3406   Business Class                             NaN         yes
# 3407      First Class                             NaN         yes
# 3408   Business Class                             NaN          no
# 3409    Economy Class                             NaN          no
#
#                                                 Content
# 0     ✅ Trip Verified |   I recently travelled from ...
# 1     Not Verified |  I paid for seats 80 A and B on...
# 2     Not Verified | The flight wasn’t that bad, alt...
# 3     ✅ Trip Verified |  I decided to treat myself a...
# 4     Not Verified |  I was very impressed with thei...
# ...                                                 ...
# 3405  I cannot believe that BA calls their plane fro...
# 3406  AMS-LHR-JNB and CPT-LHR-AMS in club. 767 betwe...
# 3407  Travelled JFK - LHR late November. The Concord...
# 3408  We flew "Business/1st class" from London to Du...
# 3409  LGW-TFS in November 2014. Flight left Gatwick ...
#
# [3410 rows x 11 columns]

# %%
#splits the Content column into two new columns, Verification_Status and Comment, based on the delimiter "|".
# Define a function to handle the conditional splitting
def split_content(content):
    # Check if "|" exists in the content
    if "|" in content:
        # Split into Verification_Status and Comment
        return content.split("|", 1)
    else:
        # If "|" is not found, set Verification_Status to None and Comment to the full content
        return [None, content]

# Apply the function to the 'Content' column and expand into two new columns
review_df[["Verification_Status", "Comment"]] = review_df["Content"].apply(split_content).apply(pandas.Series)

# Display the DataFrame to confirm changes
review_df
# Out:
#                                       Title             Author  \
# 0                 Never fly with them again     Erika Greyling
# 1          Still have not heard any updates          S Wozniak
# 2                      Cabin crew were nice   Barnaby Emmerson
# 3     Support staff wash their hands of you  Charlotte Parsons
# 4             No fuss, no bother experience       R. Wrightman
# ...                                     ...                ...
# 3405        British airways customer review            J Smith
# 3406        British airways customer review       Boone Pieter
# 3407        British airways customer review             R King
# 3408        British airways customer review       Tom Gleinser
# 3409        British airways customer review        H Blackhall
#
#              Country  Rating  Overall_Rating Date_Published Type_of_Traveller  \
# 0     United Kingdom     1.0            10.0     2024-11-03    Couple Leisure
# 1      United States     3.0            10.0     2024-11-03    Couple Leisure
# 2     United Kingdom     7.0            10.0     2024-11-03    Family Leisure
# 3     United Kingdom     1.0            10.0     2024-11-02    Family Leisure
# 4             Canada     9.0            10.0     2024-11-02      Solo Leisure
# ...              ...     ...             ...            ...               ...
# 3405   United States     1.0            10.0     2014-12-18               NaN
# 3406     Netherlands     7.0            10.0     2014-12-18               NaN
# 3407  United Kingdom     8.0            10.0     2014-12-18               NaN
# 3408   United States     2.0            10.0     2014-12-18               NaN
# 3409  United Kingdom     3.0            10.0     2014-12-18               NaN
#
#             Seat_Type                           Route Recommended  \
# 0       Economy Class       Munich to London Heathrow          no
# 1     Premium Economy              Heathrow to Boston          no
# 2       Economy Class  Los Angeles to London Heathrow         yes
# 3     Premium Economy             Vancouver to London          no
# 4       Economy Class            Vancouver to Gatwick         yes
# ...               ...                             ...         ...
# 3405   Business Class                             NaN          no
# 3406   Business Class                             NaN         yes
# 3407      First Class                             NaN         yes
# 3408   Business Class                             NaN          no
# 3409    Economy Class                             NaN          no
#
#                                                 Content Verification_Status  \
# 0     ✅ Trip Verified |   I recently travelled from ...    ✅ Trip Verified
# 1     Not Verified |  I paid for seats 80 A and B on...       Not Verified
# 2     Not Verified | The flight wasn’t that bad, alt...       Not Verified
# 3     ✅ Trip Verified |  I decided to treat myself a...    ✅ Trip Verified
# 4     Not Verified |  I was very impressed with thei...       Not Verified
# ...                                                 ...                 ...
# 3405  I cannot believe that BA calls their plane fro...                None
# 3406  AMS-LHR-JNB and CPT-LHR-AMS in club. 767 betwe...                None
# 3407  Travelled JFK - LHR late November. The Concord...                None
# 3408  We flew "Business/1st class" from London to Du...                None
# 3409  LGW-TFS in November 2014. Flight left Gatwick ...                None
#
#                                                 Comment
# 0        I recently travelled from Munich to London ...
# 1       I paid for seats 80 A and B on my flight fro...
# 2      The flight wasn’t that bad, although the Infl...
# 3       I decided to treat myself and my teenage dau...
# 4       I was very impressed with their efficient bo...
# ...                                                 ...
# 3405  I cannot believe that BA calls their plane fro...
# 3406  AMS-LHR-JNB and CPT-LHR-AMS in club. 767 betwe...
# 3407  Travelled JFK - LHR late November. The Concord...
# 3408  We flew "Business/1st class" from London to Du...
# 3409  LGW-TFS in November 2014. Flight left Gatwick ...
#
# [3410 rows x 13 columns]

# %%
#drops duplicates from all columns
review_df = review_df.drop_duplicates()
review_df
# Out:
#                                       Title             Author  \
# 0                 Never fly with them again     Erika Greyling
# 1          Still have not heard any updates          S Wozniak
# 2                      Cabin crew were nice   Barnaby Emmerson
# 3     Support staff wash their hands of you  Charlotte Parsons
# 4             No fuss, no bother experience       R. Wrightman
# ...                                     ...                ...
# 3405        British airways customer review            J Smith
# 3406        British airways customer review       Boone Pieter
# 3407        British airways customer review             R King
# 3408        British airways customer review       Tom Gleinser
# 3409        British airways customer review        H Blackhall
#
#              Country  Rating  Overall_Rating Date_Published Type_of_Traveller  \
# 0     United Kingdom     1.0            10.0     2024-11-03    Couple Leisure
# 1      United States     3.0            10.0     2024-11-03    Couple Leisure
# 2     United Kingdom     7.0            10.0     2024-11-03    Family Leisure
# 3     United Kingdom     1.0            10.0     2024-11-02    Family Leisure
# 4             Canada     9.0            10.0     2024-11-02      Solo Leisure
# ...              ...     ...             ...            ...               ...
# 3405   United States     1.0            10.0     2014-12-18               NaN
# 3406     Netherlands     7.0            10.0     2014-12-18               NaN
# 3407  United Kingdom     8.0            10.0     2014-12-18               NaN
# 3408   United States     2.0            10.0     2014-12-18               NaN
# 3409  United Kingdom     3.0            10.0     2014-12-18               NaN
#
#             Seat_Type                           Route Recommended  \
# 0       Economy Class       Munich to London Heathrow          no
# 1     Premium Economy              Heathrow to Boston          no
# 2       Economy Class  Los Angeles to London Heathrow         yes
# 3     Premium Economy             Vancouver to London          no
# 4       Economy Class            Vancouver to Gatwick         yes
# ...               ...                             ...         ...
# 3405   Business Class                             NaN          no
# 3406   Business Class                             NaN         yes
# 3407      First Class                             NaN         yes
# 3408   Business Class                             NaN          no
# 3409    Economy Class                             NaN          no
#
#                                                 Content Verification_Status  \
# 0     ✅ Trip Verified |   I recently travelled from ...    ✅ Trip Verified
# 1     Not Verified |  I paid for seats 80 A and B on...       Not Verified
# 2     Not Verified | The flight wasn’t that bad, alt...       Not Verified
# 3     ✅ Trip Verified |  I decided to treat myself a...    ✅ Trip Verified
# 4     Not Verified |  I was very impressed with thei...       Not Verified
# ...                                                 ...                 ...
# 3405  I cannot believe that BA calls their plane fro...                None
# 3406  AMS-LHR-JNB and CPT-LHR-AMS in club. 767 betwe...                None
# 3407  Travelled JFK - LHR late November. The Concord...                None
# 3408  We flew "Business/1st class" from London to Du...                None
# 3409  LGW-TFS in November 2014. Flight left Gatwick ...                None
#
#                                                 Comment
# 0        I recently travelled from Munich to London ...
# 1       I paid for seats 80 A and B on my flight fro...
# 2      The flight wasn’t that bad, although the Infl...
# 3       I decided to treat myself and my teenage dau...
# 4       I was very impressed with their efficient bo...
# ...                                                 ...
# 3405  I cannot believe that BA calls their plane fro...
# 3406  AMS-LHR-JNB and CPT-LHR-AMS in club. 767 betwe...
# 3407  Travelled JFK - LHR late November. The Concord...
# 3408  We flew "Business/1st class" from London to Du...
# 3409  LGW-TFS in November 2014. Flight left Gatwick ...
#
# [3373 rows x 13 columns]

# %%
# Where route is N/A, extract the route from the comment column (Not working as expected, ask for assistance)
# Adjusted get_route_from_comment function
def get_route_from_comment(comment):
    # Regex pattern to capture country pairs like "Country1 to Country2" or "Country1 - Country2"
    match = re.search(r'(\b\w+\b)\s*(?:to|-)\s*(\b\w+\b)', comment)
    if match:
        # Extract the matched groups
        country1, country2 = match.groups()
        
        # Return the formatted route string
        return f"{country1} to {country2}"
    return None  # Return None if no match is found

# Define a function to update Route based on Comment
def update_route(row):
    # If the Route is 'N/A', we want to attempt to extract a route from Comment
    if row['Route'] == 'N/A':
        route = get_route_from_comment(row['Comment'])
        # If a route is extracted, return it; otherwise, return 'N/A'
        return route if route else 'N/A'
    return row['Route']

# Apply the function to the DataFrame using .loc to avoid SettingWithCopyWarning
review_df.loc[:, 'Route'] = review_df.apply(update_route, axis=1)

# Check the updated DataFrame
review_df
# Out:
#                                       Title             Author  \
# 0                 Never fly with them again     Erika Greyling
# 1          Still have not heard any updates          S Wozniak
# 2                      Cabin crew were nice   Barnaby Emmerson
# 3     Support staff wash their hands of you  Charlotte Parsons
# 4             No fuss, no bother experience       R. Wrightman
# ...                                     ...                ...
# 3405        British airways customer review            J Smith
# 3406        British airways customer review       Boone Pieter
# 3407        British airways customer review             R King
# 3408        British airways customer review       Tom Gleinser
# 3409        British airways customer review        H Blackhall
#
#              Country  Rating  Overall_Rating Date_Published Type_of_Traveller  \
# 0     United Kingdom     1.0            10.0     2024-11-03    Couple Leisure
# 1      United States     3.0            10.0     2024-11-03    Couple Leisure
# 2     United Kingdom     7.0            10.0     2024-11-03    Family Leisure
# 3     United Kingdom     1.0            10.0     2024-11-02    Family Leisure
# 4             Canada     9.0            10.0     2024-11-02      Solo Leisure
# ...              ...     ...             ...            ...               ...
# 3405   United States     1.0            10.0     2014-12-18               NaN
# 3406     Netherlands     7.0            10.0     2014-12-18               NaN
# 3407  United Kingdom     8.0            10.0     2014-12-18               NaN
# 3408   United States     2.0            10.0     2014-12-18               NaN
# 3409  United Kingdom     3.0            10.0     2014-12-18               NaN
#
#             Seat_Type                           Route Recommended  \
# 0       Economy Class       Munich to London Heathrow          no
# 1     Premium Economy              Heathrow to Boston          no
# 2       Economy Class  Los Angeles to London Heathrow         yes
# 3     Premium Economy             Vancouver to London          no
# 4       Economy Class            Vancouver to Gatwick         yes
# ...               ...                             ...         ...
# 3405   Business Class                             NaN          no
# 3406   Business Class                             NaN         yes
# 3407      First Class                             NaN         yes
# 3408   Business Class                             NaN          no
# 3409    Economy Class                             NaN          no
#
#                                                 Content Verification_Status  \
# 0     ✅ Trip Verified |   I recently travelled from ...    ✅ Trip Verified
# 1     Not Verified |  I paid for seats 80 A and B on...       Not Verified
# 2     Not Verified | The flight wasn’t that bad, alt...       Not Verified
# 3     ✅ Trip Verified |  I decided to treat myself a...    ✅ Trip Verified
# 4     Not Verified |  I was very impressed with thei...       Not Verified
# ...                                                 ...                 ...
# 3405  I cannot believe that BA calls their plane fro...                None
# 3406  AMS-LHR-JNB and CPT-LHR-AMS in club. 767 betwe...                None
# 3407  Travelled JFK - LHR late November. The Concord...                None
# 3408  We flew "Business/1st class" from London to Du...                None
# 3409  LGW-TFS in November 2014. Flight left Gatwick ...                None
#
#                                                 Comment
# 0        I recently travelled from Munich to London ...
# 1       I paid for seats 80 A and B on my flight fro...
# 2      The flight wasn’t that bad, although the Infl...
# 3       I decided to treat myself and my teenage dau...
# 4       I was very impressed with their efficient bo...
# ...                                                 ...
# 3405  I cannot believe that BA calls their plane fro...
# 3406  AMS-LHR-JNB and CPT-LHR-AMS in club. 767 betwe...
# 3407  Travelled JFK - LHR late November. The Concord...
# 3408  We flew "Business/1st class" from London to Du...
# 3409  LGW-TFS in November 2014. Flight left Gatwick ...
#
# [3373 rows x 13 columns]

# %%
# add a month and year column in the original dataset
#.loc explicitly specifies where the assignment should happen. This avoids ambiguity between modifying a slice and the parent DataFrame.
review_df.loc[:, 'Month_Posted'] = review_df['Date_Published'].dt.month
review_df.loc[:, 'Year_Posted'] = review_df['Date_Published'].dt.year
review_df.head()
# Out:
# C:\Users\smule\AppData\Local\Temp\ipykernel_16148\1510166770.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df.loc[:, 'Month_Posted'] = review_df['Date_Published'].dt.month
# C:\Users\smule\AppData\Local\Temp\ipykernel_16148\1510166770.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_df.loc[:, 'Year_Posted'] = review_df['Date_Published'].dt.year
#                                    Title             Author         Country  \
# 0              Never fly with them again     Erika Greyling  United Kingdom
# 1       Still have not heard any updates          S Wozniak   United States
# 2                   Cabin crew were nice   Barnaby Emmerson  United Kingdom
# 3  Support staff wash their hands of you  Charlotte Parsons  United Kingdom
# 4          No fuss, no bother experience       R. Wrightman          Canada
#
#    Rating  Overall_Rating Date_Published Type_of_Traveller        Seat_Type  \
# 0     1.0            10.0     2024-11-03    Couple Leisure    Economy Class
# 1     3.0            10.0     2024-11-03    Couple Leisure  Premium Economy
# 2     7.0            10.0     2024-11-03    Family Leisure    Economy Class
# 3     1.0            10.0     2024-11-02    Family Leisure  Premium Economy
# 4     9.0            10.0     2024-11-02      Solo Leisure    Economy Class
#
#                             Route Recommended  \
# 0       Munich to London Heathrow          no
# 1              Heathrow to Boston          no
# 2  Los Angeles to London Heathrow         yes
# 3             Vancouver to London          no
# 4            Vancouver to Gatwick         yes
#
#                                              Content Verification_Status  \
# 0  ✅ Trip Verified |   I recently travelled from ...    ✅ Trip Verified
# 1  Not Verified |  I paid for seats 80 A and B on...       Not Verified
# 2  Not Verified | The flight wasn’t that bad, alt...       Not Verified
# 3  ✅ Trip Verified |  I decided to treat myself a...    ✅ Trip Verified
# 4  Not Verified |  I was very impressed with thei...       Not Verified
#
#                                              Comment  Month_Posted  \
# 0     I recently travelled from Munich to London ...            11
# 1    I paid for seats 80 A and B on my flight fro...            11
# 2   The flight wasn’t that bad, although the Infl...            11
# 3    I decided to treat myself and my teenage dau...            11
# 4    I was very impressed with their efficient bo...            11
#
#    Year_Posted
# 0         2024
# 1         2024
# 2         2024
# 3         2024
# 4         2024

# %%
# Save to CSV without the index
review_df.to_csv("BA_clean_dataset.csv", index=False)

print("Dataset saved as BA_clean_dataset.csv")
# Out:
# Dataset saved as BA_clean_dataset.csv

# %%
review_df.head()
# Out:
#                                    Title             Author         Country  \
# 0              Never fly with them again     Erika Greyling  United Kingdom
# 1       Still have not heard any updates          S Wozniak   United States
# 2                   Cabin crew were nice   Barnaby Emmerson  United Kingdom
# 3  Support staff wash their hands of you  Charlotte Parsons  United Kingdom
# 4          No fuss, no bother experience       R. Wrightman          Canada
#
#    Rating  Overall_Rating Date_Published Type_of_Traveller        Seat_Type  \
# 0     1.0            10.0     2024-11-03    Couple Leisure    Economy Class
# 1     3.0            10.0     2024-11-03    Couple Leisure  Premium Economy
# 2     7.0            10.0     2024-11-03    Family Leisure    Economy Class
# 3     1.0            10.0     2024-11-02    Family Leisure  Premium Economy
# 4     9.0            10.0     2024-11-02      Solo Leisure    Economy Class
#
#                             Route Recommended  \
# 0       Munich to London Heathrow          no
# 1              Heathrow to Boston          no
# 2  Los Angeles to London Heathrow         yes
# 3             Vancouver to London          no
# 4            Vancouver to Gatwick         yes
#
#                                              Content Verification_Status  \
# 0  ✅ Trip Verified |   I recently travelled from ...    ✅ Trip Verified
# 1  Not Verified |  I paid for seats 80 A and B on...       Not Verified
# 2  Not Verified | The flight wasn’t that bad, alt...       Not Verified
# 3  ✅ Trip Verified |  I decided to treat myself a...    ✅ Trip Verified
# 4  Not Verified |  I was very impressed with thei...       Not Verified
#
#                                              Comment  Month_Posted  \
# 0     I recently travelled from Munich to London ...            11
# 1    I paid for seats 80 A and B on my flight fro...            11
# 2   The flight wasn’t that bad, although the Infl...            11
# 3    I decided to treat myself and my teenage dau...            11
# 4    I was very impressed with their efficient bo...            11
#
#    Year_Posted
# 0         2024
# 1         2024
# 2         2024
# 3         2024
# 4         2024
